# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy as sp
import yfinance as yf
# 한글폰트 출력 가능 코드
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
df = pd.read_csv("./dataset/종전외개기_시가대비_환율차분.csv")
df = pd.DataFrame(df)
df_1=df[['날짜','시가총액대비']]
df_1.to_csv('시가총액대비&날짜.csv')

# %%
df_2 = pd.read_csv("./dataset/외국인_증권투자_현황.csv",encoding="cp949")
df_2 = pd.DataFrame(df_2)
df_2
# Out:
#          날짜  외국인보유금액  시가총액대비
# 0    200501    184.8    42.9
# 1    200502    200.3    42.7
# 2    200503    189.1    42.2
# 3    200504    177.2    41.9
# 4    200505    188.0    41.7
# ..      ...      ...     ...
# 202  202111    691.1    33.0
# 203  202112    738.9    33.5
# 204  202201    685.7    32.7
# 205  202202    687.3    32.4
# 206  202203    684.4    31.6
#
# [207 rows x 3 columns]

# %%
df_2.drop("날짜",axis=1,inplace=True)
df_2
# Out:
#      외국인보유금액  시가총액대비
# 0      184.8    42.9
# 1      200.3    42.7
# 2      189.1    42.2
# 3      177.2    41.9
# 4      188.0    41.7
# ..       ...     ...
# 202    691.1    33.0
# 203    738.9    33.5
# 204    685.7    32.7
# 205    687.3    32.4
# 206    684.4    31.6
#
# [207 rows x 2 columns]

# %%
# df.drop(['Unnamed: 0'],axis=1,inplace=True)
df
# Out:
#              날짜           종가  전월대비 등락률  외국인순매수  개인순매수  기관순매수  시가총액대비  \
# 0    2005-01-01   932.700012  0.041053    8538  -9523    984    42.9
# 1    2005-02-01  1011.359985  0.084336   14654  -5725  -8928    42.7
# 2    2005-03-01   965.679993 -0.045167  -20741   3820  16920    42.2
# 3    2005-04-01   911.299988 -0.056313   -3243   2291    955    41.9
# 4    2005-05-01   970.210022  0.064644    1048 -18304  17254    41.7
# ..          ...          ...       ...     ...    ...    ...     ...
# 202  2021-11-01  2839.010010 -0.044323   11342  16641 -11868    33.0
# 203  2021-12-01  2977.649902  0.048834   15250 -30452   8397    33.5
# 204  2022-01-01  2663.340088 -0.105556    -389  12674 -16297    32.7
# 205  2022-02-01  2699.179932  0.013457   -6207 -10135   -980    32.4
# 206  2022-03-01  2757.649902  0.021662  -23373  -3604   1769    31.6
#
#               환율     환율 차분
# 0    1025.410034  0.022751
# 1    1003.799988 -0.021075
# 2    1017.000000  0.013150
# ...

# %%
df.columns
# Out:
# Index(['날짜', '종가', '전월대비 등락률', '외국인순매수', '개인순매수', '기관순매수', '시가총액대비', '환율',
#        '환율 차분'],
#       dtype='object')

# %%
# df.drop(['날짜'],axis=1,inplace=True)
df
# Out:
#               종가  전월대비 등락률  외국인순매수  개인순매수  기관순매수  시가총액대비           환율  \
# 0     932.700012  0.041053    8538  -9523    984    42.9  1025.410034
# 1    1011.359985  0.084336   14654  -5725  -8928    42.7  1003.799988
# 2     965.679993 -0.045167  -20741   3820  16920    42.2  1017.000000
# 3     911.299988 -0.056313   -3243   2291    955    41.9   996.659973
# 4     970.210022  0.064644    1048 -18304  17254    41.7  1007.000000
# ..           ...       ...     ...    ...    ...     ...          ...
# 202  2839.010010 -0.044323   11342  16641 -11868    33.0  1190.739990
# 203  2977.649902  0.048834   15250 -30452   8397    33.5  1183.670044
# 204  2663.340088 -0.105556    -389  12674 -16297    32.7  1203.459961
# 205  2699.179932  0.013457   -6207 -10135   -980    32.4  1197.589966
# 206  2757.649902  0.021662  -23373  -3604   1769    31.6  1210.439941
#
#         환율 차분
# 0    0.022751
# 1   -0.021075
# 2    0.013150
# 3   -0.020000
# 4    0.010375
# ..        ...
# 202  0.020019
# ...

# %%
#잔차도 보기
sqrt_mse =np.sqrt(fitted_model.mse_resid)
std_res = fitted_model.resid/sqrt_mse

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
font_size = 15
 
plt.scatter( df['외국인순매수'],std_res) ## 잔차도 출력

plt.xlabel('외국인순매수', fontsize=font_size)
plt.ylabel('Residual', fontsize=font_size)
plt.show()
#특별한 패턴이 없으므로 선형모양 적합

# %%
#잔차도 보기
sqrt_mse =np.sqrt(fitted_model.mse_resid)
std_res = fitted_model.resid/sqrt_mse

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
font_size = 15
 
plt.scatter( df['개인순매수'],std_res) ## 잔차도 출력

plt.xlabel('개인순매수', fontsize=font_size)
plt.ylabel('Residual', fontsize=font_size)
plt.show()
#특별한 패턴이 없으므로 선형모양 적합

# %%
#잔차도 보기
sqrt_mse =np.sqrt(fitted_model.mse_resid)
std_res = fitted_model.resid/sqrt_mse

fig = plt.figure(figsize=(8,8))
fig.set_facecolor('white')
 
font_size = 15
 
plt.scatter( df['시가총액대비'],std_res) ## 잔차도 출력

plt.xlabel('시가총액대비', fontsize=font_size)
plt.ylabel('Residual', fontsize=font_size)
plt.show()
#특별한 패턴이 없으므로 선형모양 적합

# %%
df_3 = pd.read_csv("./환율.csv")
df_3 = pd.DataFrame(df_3)
df_3
# Out:
#      Unnamed: 0          날짜           환율
# 0             0  2005-01-31  1025.410034
# 1             1  2005-02-28  1003.799988
# 2             2  2005-03-31  1017.000000
# 3             3  2005-04-29   996.659973
# 4             4  2005-05-31  1007.000000
# ..          ...         ...          ...
# 203         203  2021-12-30  1183.670044
# 204         204  2022-01-28  1203.459961
# 205         205  2022-02-28  1197.589966
# 206         206  2022-03-31          NaN
# 207         207  2022-04-22          NaN
#
# [208 rows x 3 columns]

# %%
df_3.drop(index = [207], inplace=True)

# %%
df_3.drop(["Unnamed: 0","날짜"],axis=1,inplace=True)

# %%
df_3["환율"][206] = 1210.439941

# %%
df_3
# Out:
#               환율
# 0    1025.410034
# 1    1003.799988
# 2    1017.000000
# 3     996.659973
# 4    1007.000000
# ..           ...
# 202  1190.739990
# 203  1183.670044
# 204  1203.459961
# 205  1197.589966
# 206  1210.439941
#
# [207 rows x 1 columns]

# %%
df = df.join(df_3)

# %%
df
# Out:
#              날짜           종가  전월대비 등락률  외국인순매수  개인순매수  기관순매수  시가총액대비  \
# 0    2005-01-01   932.700012  0.041053    8538  -9523    984    42.9
# 1    2005-02-01  1011.359985  0.084336   14654  -5725  -8928    42.7
# 2    2005-03-01   965.679993 -0.045167  -20741   3820  16920    42.2
# 3    2005-04-01   911.299988 -0.056313   -3243   2291    955    41.9
# 4    2005-05-01   970.210022  0.064644    1048 -18304  17254    41.7
# ..          ...          ...       ...     ...    ...    ...     ...
# 202  2021-11-01  2839.010010 -0.044323   11342  16641 -11868    33.0
# 203  2021-12-01  2977.649902  0.048834   15250 -30452   8397    33.5
# 204  2022-01-01  2663.340088 -0.105556    -389  12674 -16297    32.7
# 205  2022-02-01  2699.179932  0.013457   -6207 -10135   -980    32.4
# 206  2022-03-01  2757.649902  0.021662  -23373  -3604   1769    31.6
#
#               환율
# 0    1025.410034
# 1    1003.799988
# 2    1017.000000
# 3     996.659973
# 4    1007.000000
# ..           ...
# ...

# %%
df["환율 차분"] = (df["환율"]-df["환율"].shift(1))/df["환율"].shift(1)

# %%
df
# Out:
#              날짜           종가  전월대비 등락률  외국인순매수  개인순매수  기관순매수  시가총액대비  \
# 0    2005-01-01   932.700012  0.041053    8538  -9523    984    42.9
# 1    2005-02-01  1011.359985  0.084336   14654  -5725  -8928    42.7
# 2    2005-03-01   965.679993 -0.045167  -20741   3820  16920    42.2
# 3    2005-04-01   911.299988 -0.056313   -3243   2291    955    41.9
# 4    2005-05-01   970.210022  0.064644    1048 -18304  17254    41.7
# ..          ...          ...       ...     ...    ...    ...     ...
# 202  2021-11-01  2839.010010 -0.044323   11342  16641 -11868    33.0
# 203  2021-12-01  2977.649902  0.048834   15250 -30452   8397    33.5
# 204  2022-01-01  2663.340088 -0.105556    -389  12674 -16297    32.7
# 205  2022-02-01  2699.179932  0.013457   -6207 -10135   -980    32.4
# 206  2022-03-01  2757.649902  0.021662  -23373  -3604   1769    31.6
#
#               환율     환율 차분
# 0    1025.410034       NaN
# 1    1003.799988 -0.021075
# 2    1017.000000  0.013150
# ...

# %%
df['환율 차분'][0] = (1025.410034 -1002.599976)/1002.599976
# Out:
# C:\ProgramData\Anaconda3\envs\myenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#              날짜           종가  전월대비 등락률  외국인순매수  개인순매수  기관순매수  시가총액대비  \
# 0    2005-01-01   932.700012  0.041053    8538  -9523    984    42.9
# 1    2005-02-01  1011.359985  0.084336   14654  -5725  -8928    42.7
# 2    2005-03-01   965.679993 -0.045167  -20741   3820  16920    42.2
# 3    2005-04-01   911.299988 -0.056313   -3243   2291    955    41.9
# 4    2005-05-01   970.210022  0.064644    1048 -18304  17254    41.7
# ..          ...          ...       ...     ...    ...    ...     ...
# 202  2021-11-01  2839.010010 -0.044323   11342  16641 -11868    33.0
# 203  2021-12-01  2977.649902  0.048834   15250 -30452   8397    33.5
# 204  2022-01-01  2663.340088 -0.105556    -389  12674 -16297    32.7
# 205  2022-02-01  2699.179932  0.013457   -6207 -10135   -980    32.4
# 206  2022-03-01  2757.649902  0.021662  -23373  -3604   1769    31.6
#
#               환율     환율 차분
# 0    1025.410034  0.022751
# 1    1003.799988 -0.021075
# 2    1017.000000  0.013150
# ...

# %%
df.to_csv("종전외개기_시가대비_환율차분.csv")

# %%
from sklearn.preprocessing import MinMaxScaler
df_m= df['환율 차분'].to_numpy

df_m.reshpe(-1,1)

scaler=MinMaxScaler() ###stanrdardScaler객체 생성
scaler.fit(df_m)#iris_df로 훈련을 시킨다. fit은 데이터 변환을 위해서 기준 정보를 설정하는 역할

df_scaled=scaler.transform(df_m)  #transform()시 scale 변환된 데이터 셋이 numpy ndarray로 반환됨. 공식을 실행시켜준다고 생각하면됨.

df_mm =pd.DataFrame(data=df_scaled)#데이터 프레임화
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13552/3977799758.py in <module>
#       2 df_m= df['환율 차분'].to_numpy
#       3
# ----> 4 df_m.reshpe(-1,1)
#       5
#       6 scaler=MinMaxScaler() ###stanrdardScaler객체 생성
#
# AttributeError: 'function' object has no attribute 'reshpe'

# %%
df.to_csv("종전외개기_시가총액대비_환율.csv")

# %%
#df.to_csv("종전외개기_시가총액대비_환율.csv")

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm


# target은 종속변수, feature는 독립변수와 같다. (KOSPI 제외 Close, Volume 컬럼에 대해 feature 설정)
target = df['전월대비 등락률']
features = df.drop(['날짜','종가','전월대비 등락률','기관순매수'],axis=1)

model = sm.OLS(target, features)
fitted_model = model.fit()

# summary 함수통해 결과출력
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:               전월대비 등락률   R-squared (uncentered):                   0.346
# Model:                            OLS   Adj. R-squared (uncentered):              0.333
# Method:                 Least Squares   F-statistic:                              26.83
# Date:                Mon, 02 May 2022   Prob (F-statistic):                    7.05e-18
# Time:                        20:19:28   Log-Likelihood:                          360.77
# No. Observations:                 207   AIC:                                     -713.5
# Df Residuals:                     203   BIC:                                     -700.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
# 정규성 검정 (시각화)
from scipy.stats import probplot

# 시각화 
probplot(df['환율 차분'],plot=plt) 
plt.show()

# %%
# shapiro 검정 시행
from scipy.stats import shapiro

test_stat, pval = shapiro(df['환율 차분'])

if pval < .05:
    print(f'p값이 {pval*100 : .8f}% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 있습니다.')
else:
    print(f'p값이 {pval*100 : .8f}% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 없습니다.')
    
# jarque_bera 검정 시행
from scipy.stats import jarque_bera

stats, pval = jarque_bera(df['환율 차분'])

if pval < .05:
    print(f'p값이 {pval*100 : .8f}% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 있습니다.')
else:
    print(f'p값이 {pval*100 : .8f}% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 없습니다.')
# Out:
# p값이  0.00000012% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 있습니다.
# p값이  0.00000000% 이므로 정규성을 충족한다는 귀무가설을 5% 유의수준으로 기각할 수 있습니다.
