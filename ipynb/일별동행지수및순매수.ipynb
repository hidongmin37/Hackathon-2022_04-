# %% [markdown]
# ### **경기선행지수 및 동행지수 pyplot그리기**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### **1. 데이터 업로드 및 전처리**

# %%
cycle_data=pd.read_csv("./dataset/cycle_data.csv")
cycle_data.columns = ['date','동행지수','선행지수']
cycle_data.head(5)

for i in range(0,242):
    cycle_data['date'][i]=str(cycle_data['date'][i])+str("01")

cycle_data['date']=pd.to_datetime(cycle_data['date'])
cycle_data
cycle_data_2005=cycle_data.loc[(cycle_data['date'] >= '2005-01-01') & (cycle_data['date'] <= '2022-04-01')]
cycle_data_2005
# Out:
# C:\Users\jangd\AppData\Local\Temp\ipykernel_17960\3478577130.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cycle_data['date'][i]=str(cycle_data['date'][i])+str("01")
#           date   동행지수   선행지수
# 36  2005-01-01   99.0   98.8
# 37  2005-02-01   98.7   99.1
# 38  2005-03-01   98.8   99.6
# 39  2005-04-01   98.6   99.6
# 40  2005-05-01   98.7   99.3
# ..         ...    ...    ...
# 237 2021-10-01  100.9  100.7
# 238 2021-11-01  101.1  100.4
# 239 2021-12-01  101.8  100.2
# 240 2022-01-01  102.4  100.1
# 241 2022-02-01  102.6   99.8
#
# [206 rows x 3 columns]

# %%
type(cycle_data)
cycle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    242 non-null    datetime64[ns]
#  1   동행지수    242 non-null    float64
#  2   선행지수    242 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 5.8 KB

# %% [markdown]
# ##### 선행동행지수 기준선 100 만들기

# %%
#242개월에 대응하는 기준선 100 만들기 위해 np.full사용
a=np.full((1,242),100) 
#array를 list로 변환
b=a.tolist()
#전치해 데이터 프레임으로 생성
c=pd.DataFrame(b).T
c.columns=['기준']
c
# Out:
#       기준
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# ..   ...
# 237  100
# 238  100
# 239  100
# 240  100
# 241  100
#
# [242 rows x 1 columns]

# %% [markdown]
# #### **2. pyplot으로 데이터 시각화 하기**

# %%
import plotly.express as px
import plotly.io as pio
import os #꼭 넣기
pio.renderers.default = "notebook_connected"
import numpy as np
import plotly.graph_objects as go

# %%
fig = px.line(cycle_data, x="date", y="동행지수", title='동행지수')
fig = px.line(cycle_data, x="date", y="선행지수", title='선행지수')

fig.add_trace(go.Scatter(x=cycle_data['date'],y=cycle_data['동행지수'],
             line=dict(dash='solid',shape='spline',color='red'), name='동행지수'))
fig.add_trace(go.Scatter(x=cycle_data['date'],y=cycle_data['선행지수'],
             line=dict(dash='solid',shape='spline',color='blue'), name='선행지수'))
fig.add_trace(go.Scatter(x=cycle_data['date'],y=c['기준'],
             line=dict(dash='dashdot',color='grey'), name='기준'))
# 기본 폰트 설정
# fig.add_trace(go.Scatter(x=data['date'],y=b,
#              mode='lines', name='선행지수'))


layout_font = {'font':dict(size=18,color='#60606e',family='Franklin Gothic' )}
fig.update_layout(title='<b>우리나라 경기종합지수 흐름 </b>', **layout_font)


fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="84a847bc-161c-441e-a49e-3a74fbeb2a15" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("84a847bc-161c-441e-a49e-3a74fbeb2a15")) {
#                     Plotly.newPlot(
# ...

# %%
# #plot으로 그리기 위해 리스트로 변환해주기 - plt쓸때 필요

# #1. 날짜 데이터에 날짜 형식을 맞추기 위해 01을 추가 한 후 리스트로 변환하기
# date=pd.DataFrame(cycle_data['date'])
# list=[]
# for i in range(242):
#     # print(dd['date'][i])
#     list.append(str(date['date'][i])+"01")
#     int(date['date'][i])
# cycle_data['date']=list
# cycle_data['date'] = pd.to_datetime(cycle_data['date'])
# cycle_data

# #2. 동행지수 리스트로 변환하기
# dong = pd.DataFrame(cycle_data['동행지수'])
# dong_2=[]
# for j in range(242):
#     dong_2.append(dong['동행지수'][j])
# dong_2

# #3. 선행지수 리스트로 변환하기
# sun = pd.DataFrame(cycle_data['선행지수'])
# sun_2=[]
# for z in range(242):
#     sun_2.append(sun['선행지수'][z])

# %%
cycle_month=pd.read_csv("C:/Users/jangd/OneDrive/사진/문서/GitHub/git_hub_0420/python/project/dataset/월별_외국인순매수_합과_전월대비 등락률_이상치제거전.csv")
cycle_month

cycle_month.dtypes
cycle_month.drop(index=207,inplace=True)

# %%
month_fill_data=pd.read_csv("C:/Users/jangd/OneDrive/사진/문서/GitHub/git_hub_0420/python/project/dataset/결측치_채워준_월별데이터.csv")
month_fill_data.columns=['아','날짜','전월대비 등락률']
month_fill_data.drop('아',axis=1,inplace=True)

cycle_month['전월대비 등락률']=month_fill_data['전월대비 등락률']
cycle_month.to_csv("결측치_채워준_월별데이터__.csv")
cycle_month.drop(index=206,inplace=True)

# %%
fill=pd.read_csv('C:/Users/jangd/OneDrive/사진/문서/GitHub/git_hub_0420/python/project/dataset/pre_kospi.csv')
fill.drop('등락율',axis=1,inplace=True)
fill['날짜']=pd.to_datetime(fill['날짜'])
fill.dtypes
# Out:
# Unnamed: 0             int64
# 종가                   float64
# 날짜            datetime64[ns]
# 개인순매수                  int64
# 외국인순매수                 int64
# 기관순매수                  int64
# dtype: object

# %%
fill_first=[]
numbers = list(range(len(cycle_data_2005['동행지수'])))
cycle_data_2005['label']=numbers


cycle_data_2005['label'] = np.where(cycle_data_2005['동행지수']>=100, 1, 0)
cycle_data_2005.to_csv('동행지수레이블.csv')
# Out:
# C:\Users\jangd\AppData\Local\Temp\ipykernel_17960\3747589683.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\jangd\AppData\Local\Temp\ipykernel_17960\3747589683.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(0,6322):
    fill_first.append(i)
fill_first=pd.DataFrame(fill_first)
fill_first['날짜']=pd.date_range(start='2005-01-03',end='2022-04-25')
fill_first.columns=['처음','날짜']
fill_first.drop('처음',axis=1,inplace=True)
fill_first['날짜']=pd.to_datetime(fill_first['날짜'])
fill_first.dtypes
# Out:
# 날짜    datetime64[ns]
# dtype: object

# %%
fill_merge=pd.merge(left = fill_first, right = fill, how = "left", on = "날짜")
fill_merge
# Out:
#              날짜  Unnamed: 0       종가    개인순매수  외국인순매수   기관순매수
# 0    2005-01-03      4280.0   893.71   -488.0   995.0  -507.0
# 1    2005-01-04      4279.0   886.90    -63.0   397.0  -334.0
# 2    2005-01-05      4278.0   885.19     10.0   246.0  -256.0
# 3    2005-01-06      4277.0   871.28    858.0    -6.0  -852.0
# 4    2005-01-07      4276.0   870.84   1143.0   178.0 -1321.0
# ...         ...         ...      ...      ...     ...     ...
# 6317 2022-04-21         2.0  2728.21  -5667.0  -597.0  6366.0
# 6318 2022-04-22         1.0  2704.71   8362.0 -1556.0 -6975.0
# 6319 2022-04-23         NaN      NaN      NaN     NaN     NaN
# 6320 2022-04-24         NaN      NaN      NaN     NaN     NaN
# 6321 2022-04-25         0.0  2657.13  10221.0 -6542.0 -3825.0
#
# [6322 rows x 6 columns]
