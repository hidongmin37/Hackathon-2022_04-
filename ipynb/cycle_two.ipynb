# %% [markdown]
# ### **경기선행지수 및 동행지수 pyplot그리기**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #### **1. 데이터 업로드 및 전처리**

# %%
cycle_data=pd.read_csv("./data/cycle_data.csv")
cycle_data.columns = ['date','동행지수','선행지수']
cycle_data.head(5)

cycle_data['date']
# Out:
# 0      200201
# 1      200202
# 2      200203
# 3      200204
# 4      200205
#         ...
# 237    202110
# 238    202111
# 239    202112
# 240    202201
# 241    202202
# Name: date, Length: 242, dtype: int64

# %% [markdown]
# ##### **날짜 데이터 전처리**

# %%
# 문자로 바꾸고 01을 붙인다.
for i in range(0,242):
     cycle_data['date'][i]=str(cycle_data['date'][i])+str("01")

cycle_data['date'] =pd.to_datetime(cycle_data['date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16220\2484174063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cycle_data['date'][i]=str(cycle_data['date'][i])+str("01")

# %%
type(cycle_data)
cycle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    242 non-null    datetime64[ns]
#  1   동행지수    242 non-null    float64
#  2   선행지수    242 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 5.8 KB

# %% [markdown]
# ##### 선행동행지수 기준선 100 만들기

# %%
#242개월에 대응하는 기준선 100 만들기 위해 np.full사용
a=np.full((1,242),100) 
#array를 list로 변환
b=a.tolist()
#전치해 데이터 프레임으로 생성
c=pd.DataFrame(b).T
c.columns=['기준']
c
# Out:
#       기준
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# ..   ...
# 237  100
# 238  100
# 239  100
# 240  100
# 241  100
#
# [242 rows x 1 columns]

# %% [markdown]
# #### **2. pyplot으로 데이터 시각화 하기**

# %%
import plotly.express as px
import plotly.io as pio
import os #꼭 넣기
pio.renderers.default = "notebook_connected"
import numpy as np
import plotly.graph_objects as go

# %%
fig = px.line(cycle_data, x="date", y="동행지수", title='동행지수')
fig = px.line(cycle_data, x="date", y="선행지수", title='선행지수')

fig.add_trace(go.Scatter(x=cycle_data['date'],y=cycle_data['동행지수'],
             line=dict(dash='solid',shape='spline',color='red'), name='동행지수'))
fig.add_trace(go.Scatter(x=cycle_data['date'],y=cycle_data['선행지수'],
             line=dict(dash='solid',shape='spline',color='blue'), name='선행지수'))
fig.add_trace(go.Scatter(x=cycle_data['date'],y=c['기준'],
             line=dict(dash='dashdot',color='grey'), name='기준'))
# 기본 폰트 설정
# fig.add_trace(go.Scatter(x=data['date'],y=b,
#              mode='lines', name='선행지수'))


layout_font = {'font':dict(size=18,color='#60606e',family='Franklin Gothic' )}
fig.update_layout(title='<b>우리나라 경기종합지수 흐름</b>', **layout_font)


fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="95dcf83d-6ea8-49a2-911a-2ff323260f72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95dcf83d-6ea8-49a2-911a-2ff323260f72")) {                    Plotly.newPlot(                        "95dcf83d-6ea8-49a2-911a-2ff323260f72",                        [{"hovertemplate":"date=%{x}<br>\uc120\ud589\uc9c0\uc218=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2002-01-01T00:00:00","2002-02-01T00:00:00","2002-03-01T00:00:00","2002-04-01T00:00:00","2002-05-01T00:00:00","2002-06-01T00:00:00","2002-07-01T00:00:00","2002-08-01T00:00:00","2002-09-01T00:00:00","2002-10-01T00:00:00","2002-11-01T00:00:00","2002-12-01T00:00:00","2003-01-01T00:00:00","2003-02-01T00:00:00","2003-03-01T00:00:00","2003-04-01T00:00:00","2003-05-01T00:00:00","2003-06-01T00:00:00","2003-07-01T00:00:00","2003-08-01T00:00:00","2003-09-01T00:00:00","2003-10-01T00:00:00","2003-11-01T00:00:00","2003-12-01T00:00:00","2004-01-01T00:00:00","2004-02-01T00:00:00","2004-03-01T00:00:00","2004-04-01T00:00:00","2004-05-01T00:00:00","2004-06-01T00:00:00","2004-07-01T00:00:00","2004-08-01T00:00:00","2004-09-01T00:00:00","2004-10-01T00:00:00","2004-11-01T00:00:00","2004-12-01T00:00:00","2005-01-01T00:00:00","2005-02-01T00:00:00","2005-03-01T00:00:00","2005-04-01T00:00:00","2005-05-01T00:00:00","2005-06-01T00:00:00","2005-07-01T00:00:00","2005-08-01T00:00:00","2005-09-01T00:00:00","2005-10-01T00:00:00","2005-11-01T00:00:00","2005-12-01T00:00:00","2006-01-01T00:00:00","2006-02-01T00:00:00","2006-03-01T00:00:00","2006-04-01T00:00:00","2006-05-01T00:00:00","2006-06-01T00:00:00","2006-07-01T00:00:00","2006-08-01T00:00:00","2006-09-01T00:00:00","2006-10-01T00:00:00","2006-11-01T00:00:00","2006-12-01T00:00:00","2007-01-01T00:00:00","2007-02-01T00:00:00","2007-03-01T00:00:00","2007-04-01T00:00:00","2007-05-01T00:00:00","2007-06-01T00:00:00","2007-07-01T00:00:00","2007-08-01T00:00:00","2007-09-01T00:00:00","2007-10-01T00:00:00","2007-11-01T00:00:00","2007-12-01T00:00:00","2008-01-01T00:00:00","2008-02-01T00:00:00","2008-03-01T00:00:00","2008-04-01T00:00:00","2008-05-01T00:00:00","2008-06-01T00:00:00","2008-07-01T00:00:00","2008-08-01T00:00:00","2008-09-01T00:00:00","2008-10-01T00:00:00","2008-11-01T00:00:00","2008-12-01T00:00:00","2009-01-01T00:00:00","2009-02-01T00:00:00","2009-03-01T00:00:00","2009-04-01T00:00:00","2009-05-01T00:00:00","2009-06-01T00:00:00","2009-07-01T00:00:00","2009-08-01T00:00:00","2009-09-01T00:00:00","2009-10-01T00:00:00","2009-11-01T00:00:00","2009-12-01T00:00:00","2010-01-01T00:00:00","2010-02-01T00:00:00","2010-03-01T00:00:00","2010-04-01T00:00:00","2010-05-01T00:00:00","2010-06-01T00:00:00","2010-07-01T00:00:00","2010-08-01T00:00:00","2010-09-01T00:00:00","2010-10-01T00:00:00","2010-11-01T00:00:00","2010-12-01T00:00:00","2011-01-01T00:00:00","2011-02-01T00:00:00","2011-03-01T00:00:00","2011-04-01T00:00:00","2011-05-01T00:00:00","2011-06-01T00:00:00","2011-07-01T00:00:00","2011-08-01T00:00:00","2011-09-01T00:00:00","2011-10-01T00:00:00","2011-11-01T00:00:00","2011-12-01T00:00:00","2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","20 ...

# %%
# #plot으로 그리기 위해 리스트로 변환해주기 - plt쓸때 필요

# #1. 날짜 데이터에 날짜 형식을 맞추기 위해 01을 추가 한 후 리스트로 변환하기
# date=pd.DataFrame(cycle_data['date'])
# list=[]
# for i in range(242):
#     # print(dd['date'][i])
#     list.append(str(date['date'][i])+"01")
#     int(date['date'][i])
# cycle_data['date']=list
# cycle_data['date'] = pd.to_datetime(cycle_data['date'])
# cycle_data

# #2. 동행지수 리스트로 변환하기
# dong = pd.DataFrame(cycle_data['동행지수'])
# dong_2=[]
# for j in range(242):
#     dong_2.append(dong['동행지수'][j])
# dong_2

# #3. 선행지수 리스트로 변환하기
# sun = pd.DataFrame(cycle_data['선행지수'])
# sun_2=[]
# for z in range(242):
#     sun_2.append(sun['선행지수'][z])
